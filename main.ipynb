# %%
print('Test')
# Out:
# Test

# %%
import matplotlib.pyplot as plt
import skimage

# load skimage bulit-in sample image
image = skimage.data.astronaut()

# display image
plt.imshow(image)
plt.show()
